# %%
import random as rd
import pandas as pd

# %%
gender = 'f'

def pid_generator(gender='m'):
    import random as rd
    pid=""
    code1=rd.randint(65,90)
    pid+=chr(code1) #chr() and ord()
    
    if gender == 'm':
        code2=1
    else:
        code2=2
    pid+=str(code2)
    
    for i in range(7): # code 3~9
        pid+=str(rd.randint(0,5))
    
    code1_table = {'A':10,'B':11,'C':12,'D':13,'E':14,'F':15,'G':16,'H':17,'I':34,
        'J':18,'K':19,'L':20,'M':21,'N':22,'O':35,'P':23,'Q':24,'R':25,
        'S':26,'T':27,'U':28,'V':29,'W':32,'X':30,'Y':31,'Z':33}
    
    pid_number=str(code1_table[pid[0]])+pid[1:]
    
    weight=[1,9,8,7,6,5,4,3,2,1]
    
    _sum=0
    for i in range(10):
        _sum+=int(pid_number[i])*weight[i]
    
    if(_sum%10==0):
        code10 = 0
    else:
        code10=10-_sum%10
    
    pid+=str(code10)
    
    return pid 

def stu_id_generator():
    year = ['111','111','111','111','111','110','111','111','111','111','111','109','111','111','111','111','111','111','111','111','111','111','111','111','111','111','111','111','111','111','111','111']
    cdc = ['0001','0002','0061','0062','0100','0111','0112','0200','0212','0211','0221','0222','0230','0300','0311','0312','0320','0331','0332','0340','0410','0420','0481','0482','0600','0611','0612','0621','0622','0623','0700','0721','0722','0800','0810','0820']
    stu_id = ''
    stu_id += rd.choice(year)
    stu_id += rd.choice(cdc)
    stu_id += str(rd.randint(0,5))
    stu_id += str(rd.randint(0,9))
    return int(stu_id)

coral_oc_used = []
def name_generator(gender='f'):
    prenom = '陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳陳林林林林林林林林林林林林林林林林林林林林林林林林林林林黃黃黃黃黃黃黃黃黃黃黃黃黃張張張張張張張張張張張張張張張張張張張張張李李李李李李李李李李李王王王王王王王王王吳吳吳吳吳吳吳吳吳蔡蔡蔡蔡蔡蔡楊楊楊楊楊楊許許許許許鄭鄭鄭鄭謝謝謝謝郭郭郭洪洪洪邱邱邱曾曾曾廖廖廖賴賴賴徐徐徐周周周葉葉葉葉蘇蘇蘇蘇蘇莊莊呂呂何何蕭蕭羅羅高高潘潘簡簡朱朱鍾鍾彭彭詹詹胡胡余余盧盧趙趙梁梁顏顏柯柯翁魏孫孫戴方宋范鄧杜傅侯曹薛丁卓馬董唐藍蔣石紀姚古連馮湯康田姜汪白鄒尤巫鐘龔嚴韓袁阮金童陸夏柳邵錢溫梅凌'
    f_nom_1 = '怡雅欣雅怡雅心佳佩佩靜雅佩佳怡婉郁怡鈺靜詩詩佳惠宜雅雅韻思玉琬怡雅怡婷惠淑馨雅佩淑宜佳珮嘉依雅欣慧芳家雅宜筱佳怡淑郁雅怡慧佩欣惠雅孟馨佩庭姿彥采亭虹月淑泳岱秉芮珊佳宜明亭新以郁雅瑜芊昱昱萱子于子意咏蕎欣偉堉又祐珊欣羽德亮懷宇盈禕綺榮暐怡心薰敬又沛琬薰芷紫子若欣若子佳奕'
    f_nom_2 = '君婷怡雯婷惠怡蓉珊珊怡玲君穎伶婷婷如婷宜婷涵慧雯君琪文如穎婷婷靜萍萱婷婷娟儀慧蓉婷芳樺瑜玲婷芳儀君瑜瑜涵靜婷琪文君雯筑潔玲玲穎如君儒庭珊禎穎禎翎耘華秀蓉心芸蓁羽如萱萱樺妤嵐凡淇婷庭儒岑欣霈妍倢筠捷喻語妮如安慈姍姍恩庭慈筑生恆庭嵐芸晴甯萱盈瑋昀晞恩恩雅葳茵芸婷榆婷寧璇甄'
    m_nom = '亨奇翰朗宏先柏鎮家豪宗翰志豪建宏志偉俊宏俊傑彥廷冠宇家瑋承翰柏翰冠廷俊賢家銘冠廷信宏威廷智偉哲瑋俊豪宗憲哲維志宏冠宏士豪惠君家榮嘉宏偉倫建志怡安明傑敏書政綺傳祥澤言棋洛肖起墨融基辯策國進為元'
    special_nom = ['鮭魚','蘿蔔','青菜','牛排','巧巧','清華','交大','米粉','貢丸','竹科']
    coral_oc_f = ['凌心','童耀光']
    coral_oc_m = ['楚天玄','謝瑛','宮向晚','楊拾春']
    speciality = rd.choices([0,1,2],(92,2,20))
    word = rd.choice([2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1])
    if(speciality==[0]):
        if(gender=='m'):
            return rd.choice(prenom)+(''.join(rd.sample(m_nom,word)))
        else:
            if (word==1):
                return rd.choice(prenom)+(rd.choice(f_nom_2))
            else:
                return rd.choice(prenom)+(rd.choice(f_nom_1))+(rd.choice(f_nom_2))
    elif(speciality==[1]):
        return rd.choice(prenom)+rd.choice(special_nom)
    else:
        if(gender=='m'):
            name = rd.choice(coral_oc_m)
        else:
            name = rd.choice(coral_oc_f)
        N_USED = True
        for k in coral_oc_used:
            if (name == k):
                N_USED = False
                break;
        if(N_USED):
            coral_oc_used.append(name) 
            return name
                
        else:
            return rd.choice(prenom)+rd.choice(special_nom)

# %%
stu_id_lst=[]
for i in range(800):
    NotRepeat = True
    stu_id = stu_id_generator()
    for k in stu_id_lst:
        if (stu_id == k):
            NotRepeat = False
    if(stu_id =='111071033' or stu_id =='111071024' or stu_id =='111071007' or  stu_id =='111071016' or  stu_id =='111071011'):
        NotRepeat = False
    if(NotRepeat):
        stu_id_lst.append(stu_id)
print(stu_id_lst)
# Out:
# [111020044, 111048244, 111081018, 111061144, 111034010, 111023021, 111080022, 111022115, 111042028, 111072134, 111031151, 111000240, 111062339, 111072235, 111042048, 111034024, 111031250, 111006222, 111062121, 111033233, 111032053, 111060005, 111020051, 111048257, 111031231, 111031200, 111062137, 111000131, 111081009, 110061210, 111006213, 111060008, 111048131, 111062133, 111022214, 111022225, 111032003, 111048212, 111048123, 111000228, 111070032, 111010042, 111010021, 111032050, 111062317, 111021253, 111042025, 111006109, 111031228, 111061200, 111011236, 111000222, 109072200, 111081032, 111062138, 109021233, 111062353, 111000146, 111072259, 111048234, 111021118, 111080026, 111042007, 111072210, 111031138, 111021116, 111072249, 111021258, 111062350, 111022153, 111010025, 110061155, 111062241, 111021222, 111000224, 111031100, 111010048, 111021207, 110042001, 111031207, 111011203, 111006219, 111006113, 111031112, 111061100, 111062326, 111080052, 111070002, 111072258, 111033132, 1110340
# ...

# %%
stu_id_lst=[]
f_name = []
m_name = []
f_password = []
m_password = []
for i in range(800):
    NotRepeat = True
    stu_id = stu_id_generator()
    for k in stu_id_lst:
        if (stu_id == k):
            NotRepeat = False
    if(stu_id =='111071033' or stu_id =='111071024' or stu_id =='111071007' or  stu_id =='111071016' or  stu_id =='111071011'):
        NotRepeat = False
    if(NotRepeat):
        stu_id_lst.append(stu_id)
#print(stu_id_lst) 

coral_oc_used = []
for i in range(500):
    f_name.append(name_generator('f'))
    f_password.append(pid_generator('f'))
for i in range(300):
    m_name.append(name_generator('m'))
    m_password.append(pid_generator('m'))
    
print(f_name)
# Out:
# ['林綺君', '朱淑婷', '林怡文', '黃又婷', '鍾宜晴', '陳雅嵐', '陳鮭魚', '張禕芳', '童耀光', '林鮭魚', '吳欣庭', '陳牛排', '陳淑喻', '陳芮儒', '高米粉', '周巧巧', '陳若文', '侯婷怡', '陳鮭魚', '林嘉芸', '楊交大', '田雅芳', '梅萱萱', '范意妤', '何芳如', '林詩萱', '凌心', '錢淑婷', '黃薰妤', '黃泳寧', '莊佳芳', '林羽玲', '簡佩伶', '唐雅萍', '鄒交大', '馬心茵', '陳偉翎', '黃堉恩', '董于華', '藍若秀', '蔡昱穎', '楊慈', '張米粉', '何淑玲', '邵于婷', '張依玲', '簡昱庭', '金德芸', '戴交大', '王惠文', '張惠婷', '呂郁筑', '莊耘', '葉怡倢', '蘇宜君', '蔡怡雯', '張萱婷', '陳又瑜', '林雅萱', '邵雅萱', '張堉瑜', '謝子晞', '石子婷', '廖孟如', '童鮭魚', '郭靜涵', '余牛排', '張新姍', '陳以晴', '邵鮭魚', '吳偉穎', '何子妤', '林郁如', '林青菜', '簡欣蓁', '林淑琪', '何子玲', '凌昱君', '郭巧巧', '董蘿蔔', '鍾宜婷', '魏宜珊', '張心婷', '林佳璇', '方暐萱', '莊敬樺', '林清華', '韓薰寧', '林雅捷', '吳雅婷', '嚴怡如', '曾淑慧', '洪珮恩', '孫淇', '蔡欣儀', '葉青菜', '黃又婷', '何泳文', '陳雅姍', '胡芳靜', '余怡心', '朱珊如', '林沛琪', '簡恆', '董意璇', '蕭巧巧', '石雅妮', '曾筱晞', '謝惠婷', '陳以君', '黃清華', '蔡佩君', '林竹科', '馬岱雯', '詹妤', '潘怡慈', '簡蘿蔔', '簡琬凡', '蘇米粉', '趙清華', '賴亮如', '林萱庭', '陳巧巧', '王雅甄', '蕭雅翎', '吳芷穎', '吳詩芳', '吳恩', '吳貢丸', '傅巧巧', '蔣巧巧', '王萱葳', '方蘿蔔', '溫慧', '高雅芸', '李雅雯', '鄭蘿蔔', '吳筱君', '張欣恩', '呂萱庭', '陳盈雯', '林子玲', '鄧靜', '謝淑雅'
# ...

# %%
for i in range(100):
    m_name.append(name_generator('m'))
    m_password.append(pid_generator('m'))

# %%
for i in range(100):
    NotRepeat = True
    stu_id = stu_id_generator()
    for k in stu_id_lst:
        if (stu_id == k):
            NotRepeat = False
    if(stu_id =='111071033' or stu_id =='111071024' or stu_id =='111071007' or  stu_id =='111071016' or  stu_id =='111071011'):
        NotRepeat = False
    if(NotRepeat):
        stu_id_lst.append(stu_id)

# %%
print(len(m_password))
print(len(stu_id_lst))
#print(stu_id_lst)
# Out:
# 400
# 755

# %%
data = []
data.append(['stu_id','password','name','gender'])
count = 1
for i in range(250):
    temp_data = []
    temp_data.append(stu_id_lst[i])
    temp_data.append(f_password[i])
    temp_data.append(f_name[i])
    temp_data.append('f')
    data.append(temp_data)

for i in range(250):
    temp_data.append(m_password[i])
    temp_data.append(m_name[i])
    temp_data.append('m')
    data.append(temp_data)
print(data)
# Out:
# [['stu_id', 'password', 'name', 'gender', 'room'], [111062345, 'W214143351', '楊玲', 'f', 'A801'], [111030014, 'P220452345', '顏雅妍', 'f', 'A801'], [111061217, 'O214545518', '李月捷', 'f', 'A801'], [111010021, 'A212310005', '凌心', 'f', 'A801'], [111048230, 'F235154242', '莊芊甄', 'f', 'A802'], [111082039, 'Y252340335', '張姿君', 'f', 'A802'], [111006246, 'N224325400', '童耀光', 'f', 'A802'], [111062250, 'R205125545', '趙羽禎', 'f', 'A802'], [111020013, 'K205445332', '侯詩君', 'f', 'A803'], [111021201, 'N231011304', '朱巧巧', 'f', 'A803'], [111006252, 'G220540326', '蘇交大', 'f', 'A803'], [111011254, 'T221303416', '張馨君', 'f', 'A803'], [111011220, 'W205202301', '李萱君', 'f', 'A804'], [111061203, 'L212232318', '徐泳婷', 'f', 'A804'], [111060048, 'G213143120', '曾鮭魚', 'f', 'A804'], [111070034, 'G211102452', '王祐樺', 'f', 'A804'], [111031132, 'N223203558', '許欣琪', 'f', 'B801'], [111060051, 'V253252351', '曾交大', 'f', 'B801'], [111048111, 'T233115346', '戴泳涵', 'f', 'B801'], [111022256, 'S255401046', '張米粉', 'f', 'B801'], [11103005
# ...

# %%
df = pd.DataFrame(data)
df.to_csv('user_test.csv',index=False,header=False)

# %%
read_file = pd.read_csv (r'C:\Users\tccha\Documents\Python\Python_Project\reserve_seat\user_test.csv')
read_file.to_excel (r'C:\Users\tccha\Documents\Python\Python_Project\reserve_seat\user_test.xlsx', index = None, header=True)

# %%
read_file = pd.read_excel (r'C:\Users\tccha\Documents\Python\Python_Project\reserve_seat\user_test.xlsx')
#read_file.to_csv (r'C:\Users\tccha\Documents\Python\Python_Project\reserve_seat\\user_new.csv', index = None, header=True)
